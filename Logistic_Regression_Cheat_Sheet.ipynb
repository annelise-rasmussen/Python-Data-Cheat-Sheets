# %% [markdown]
# # Import required libraries and packages

# %%
import warnings
warnings.filterwarnings("ignore") #this will ignore any warning messages

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd #our typical three libraries used for manipulating dataframes and visualizing data

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import train_test_split
import statsmodels.api as sm #the libraries and functions needed to train and evaluate a logistic regression model

# %% [markdown]
# # Train a logisitic regression model

# %% [markdown]
# > ## Assign IVs to an object called 'x'

# %%
x = df.drop(['Primary Key', 'DV'], axis=1) #remove primary key, the DV, and any collinear variables you may have identified

x = pd.get_dummies(data = x, drop_first = True) #dummy code any categorical IVs

# %% [markdown]
# > ## Assign DV to an object called 'y', dummy code DV

# %%
y = df['DV'] #assign DV to 'y' object
y = pd.get_dummies(data = y, drop_first = True) #dummy code the y variable so python treats it as binominal/dichotomous

# %% [markdown]
# > ## Create a training and test set for both x and y objects

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state=101) #set a test and training split

# %% [markdown]
# > ## Train model using sm.Logit()

# %%
x_train_Sm = sm.add_constand(x_train) #add an intercept value to x_train

log_reg = sm.Logit(y_train, x_train_Sm).fit() #fit the model to the training data (x and y)
print(log_reg.summary()) #display summary table

# %% [markdown]
# # Evaluate model accuracy on test set

# %%
x_test_Sm = sm.add_constant(x_test) #add an intercept value to x_test

model = LogisticRegression() #set model type to Logistic Regression (from sklearn library)
model.fit(x_train_Sm, y_train) #fit model to training data

predictions = model.predict(x_test_Sm) #use model to make predictions on test set data

# %%
print(classification_report(y_test, predictions)) #display classification accuracy metrics based on predicted vs actual values

# %% [markdown]
# # Calculate odds and probability from log-odds

# %%
odds = 2.718 ** "replace with log-odds value" #insert your own log-odds value and delete quotations marks
print("odds(DV) = ", odds)

#OR
np.exp("replace with log-odds value") #this is another way to convert log-odds to odds

# %%
p = odds/(1 + odds)
print("P(DV) = ", odds)

# %% [markdown]
# # Visualize proportions of each class of DV (e.g., yes/no, true/false, Kang/Kodos)

# %%
DV_counts = df['DV'].value_counts()

plt.pie(DV_counts.values, labels = DV_counts.index.values, autopct = '%1.1f')
plt.legend()
plt.show()
